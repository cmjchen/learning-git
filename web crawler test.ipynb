# %%
import requests
con=requests.get("http://tw.taobao.com/product/%E5%A4%9A%E6%A8%A3%E5%B1%8B-%E8%91%AB%E8%98%86-%E4%BF%9D%E6%BA%AB%E6%9D%AF.htm")
print con.text
# Out:
# <!DOCTYPE html>
# <html lang="zh-Hant" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta http-equiv="Content-Type" content="text/html; charset=big5"/>
# <title>【多樣屋-葫蘆-保溫杯】_推薦_品牌_價格- 淘寶網</title>
# <meta name="keywords" content="淘寶台灣，多樣屋-葫蘆-保溫杯，汽車保溫杯，波點保溫杯，泰福保溫杯"/>
# <meta name="description" content="淘寶網多樣屋-葫蘆-保溫杯頻道，我們從品牌、價格、評價、銷量出發，為您精選了多樣屋-葫蘆-保溫杯相關的商品。您還可以找汽車保溫杯,波點保溫杯,泰福保溫杯,派力康保溫杯"/>
# <link href="//tw.taobao.com/product/多樣屋-葫蘆-保溫杯.htm" rel="canonical">
# <script>
# window.g_config={appId:2, toolbar: false};
# </script>
# <link rel="stylesheet" href="//g.alicdn.com//sea/global/1.7.3/global-min.css">
# <script src="//g.alicdn.com/kissy/k/1.4.16/seed-min.js"></script>
# <script src="//g.alicdn.com//sea/global/1.7.3/global-min.js" charset="UTF-8"></script>
# <script>
# var d = +new Date;
# g_ks_monitor_st = d;
# KISSY.config({
#     // 開啟自動 combo 模式
#     combine:true
# 	});
# (function(S){
#     S.config({
#         packages: [{
#             name: 'fp',
# ...

# %%
payinput = {
'StartStation':'977abb69-413a-4ccf-a109-0272c24fd490',
'EndStation':'f2519629-5973-4d08-913b-479cce78a356',
'SearchDate':'2016/07/31',
'SearchTime':'18:30',
'SearchWay':'DepartureInMandarin'
}
sear =  requests.post("https://www.thsrc.com.tw/tw/TimeTable/SearchResult", data = payinput)
print sear.text
# Out:
# <!DOCTYPE html>
# <html lang="zh-tw">
#
#
#
# <meta charset="utf-8" />
# <link rel="shortcut icon" href="/Content/favicon/favicon.ico" />
# <!--<meta name="viewport" content="width=device-width, initial-scale=1.0, user-scalable=no, minimum-scale=1.0, maximum-scale=1.0" />-->
# <meta name="keywords" content="高鐵,快速,旅遊假期,遊玩">
# <meta name="description" content="台灣高鐵連結台灣南北主要城市，我們不只是交通運輸業，更是推動台灣­前進的服務業；我們代表的不僅只是速度，而是速度所帶來的現代生活新態度；我們以更文明的旅行體驗，成為你實現夢想的助力，台灣高鐵，實踐台灣新生活。">
# <meta name="author" content="mi70 uni-net" />
#
#
#     <meta http-equiv="cache-control" content="private">
#
#
# <!--Facebook SEO start-->
#
# <meta property="og:title" content="台灣高鐵" />
# <meta property="og:url" content="http://www.thsrc.com.tw/" />
# <meta property="og:image" content="http://www.thsrc.com.tw/Content/logo.jpg" />
# <!--Facebook SEO end-->
#
# <!--Google +1 start-->
# <meta itemprop="name" content="台灣高鐵" />
# ...

# %%
from bs4 import BeautifulSoup
html_sample = ' \
<html> \
<body> \
<h1 id="Title"> Hello, World! </h1> \
<a href="#" class="link"> Link1 </a> \
<a href="# link2" class="link"> Link2 </a> \
</body> \
</html> \
'
soup=BeautifulSoup(html_sample, "lxml")
print soup.select("a")[1].text
# Out:
#  Link2

# %%
import requests
from bs4 import BeautifulSoup
res = requests.get("http://tw.taobao.com/product/%E5%A4%9A%E6%A8%A3%E5%B1%8B-%E8%91%AB%E8%98%86-%E4%BF%9D%E6%BA%AB%E6%9D%AF.htm")
soup = BeautifulSoup(res.text, "lxml")
for item in soup.select('.item'):
    print item.select('strong')[0].text
# Out:
# 241.20
# 168.00
# 34.00
# 253.00
# 227.00
# 227.00
# 253.00
# 148.00
# 148.00
# 203.50
# 227.80
# 317.90
# 160.80
# 160.00
# 160.80
# 184.60
# 184.88
# 223.50
# 201.00
# 227.80
# 184.60
# 182.24
# 179.96
# 160.80
# 243.10
# 178.80
# 174.20
# 268.00
# 209.04
# 174.20
# 223.50
# 214.00
# 160.00
# 268.00
# 219.00
# 261.00
# 253.30
# 227.00
# 46.80
# 46.80
